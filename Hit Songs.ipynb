# %%
import pandas as pd

# DataSet de départ
data = pd.read_csv("data.csv", encoding="iso-8859-1")

# DataSet des Top Hit (jusqu'à 2017)
top_songs = pd.read_csv("top_data.csv", encoding="iso-8859-1")

# On filtre donc notre DataSet de départ pour conserver seuelement les musiques avec date > 2017
data_2017 = data[data["year"]<2017]

# On recherche l'existence des musiques dans le DataSet des Hit Songs pour créer une nouvelle variable de succès 
data_2017["top"] = data_2017["name"].isin(top_songs["title"])
                                                   
# Affichage de la nouvelle variable
print(data_2017["top"].value_counts())
print(data_2017["name"][data_2017["top"]==True])
# Out:
# False    141307
# True      20846
# Name: top, dtype: int64
# 32                          Loving You
# 336                   Indian Love Call
# 760                             Always
# 828                      Runaway Train
# 883                              Babel
# 1125                             Intro
# 1142                    Beautiful Love
# 1157           Try A Little Tenderness
# 1288                         Remind Me
# 1319                           Hold Me
# 1471                        Shangri-La
# 1499          I Only Have Eyes For You
# 1502                         Skin Deep
# 1512                               Cry
# 1534                     Body And Soul
# 1559                             Women
# 1561                           Rosalie
# 1584        I'll Never Stop Loving You
# 1593                              Baby
# 1596                           So What
# 1616                Georgia On My Mind
# 1619            Dancing On The Ceiling
# 1623                          The Wind
# 1635                          Cherokee
# 1695                             Lover
# 1696                             Lover
# 1723                  If You Were Mine
# 1735                              Down
# 1739                 How High The Moon
# 1813         Almost Like Being In Love
#                       ...
# 169362                           Rodeo
# 169365                          Panama
# 169373                   Something Big
# 169376                    I'm The Plug
# 169381                         Show Me
# 169384                         Breathe
# 169386                        Paradise
# 169392                 Wherever You Go
# 169393                 Jet Black Heart
# 169395                            Gone
# 169419                      California
# 169424    You Look Like I Need A Drink
# 169430                     Shaky Shaky
# 169431                       With Them
# 169436        A Little More Summertime
# 169446                      Let Her Go
# 169451                      U With Me?
# 169455                     True Colors
# 169460         For Whom The Bell Tolls
# 169461                  Foldin Clothes
# 169463                            Only
# 169464                 Forever Country
# 169469                           Paris
# 169471                        You & Me
# 169476                Perfect Illusion
# 169479                     Be Yourself
# 169483             Can I Get A Witness
# 169497                      I Miss You
# 169500                      Hallelujah
# 169502                She's Mine Pt. 2
# Name: name, Length: 20846, dtype: object
# C:\Users\DIEGO_LABO\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_2017 = data[data["year"]<2017]
data_2017[data_2017["year"]>1990]["year"].value_counts()
# Out:
# 2002    2000
# 1991    2000
# 1993    2000
# 1994    2000
# 1995    2000
# 1996    2000
# 1997    2000
# 1998    2000
# 1999    2000
# 2000    2000
# 2001    2000
# 2014    2000
# 2003    2000
# 2004    2000
# 2005    2000
# 2006    2000
# 2007    2000
# 2008    2000
# 2009    2000
# 2010    2000
# 2011    2000
# 2012    2000
# 2013    2000
# 1992    2000
# 2016    1969
# 2015    1931
# Name: year, dtype: int64
